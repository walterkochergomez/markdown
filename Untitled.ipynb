# %%
markitdown CONTRATO DE ARRENDAMIENTO DPTO 1603.pdf > document.md
# Out:
#   Cell In[1], line 1
#     markitdown CONTRATO DE ARRENDAMIENTO DPTO 1603.pdf > document.md
#                                                   ^
# SyntaxError: invalid decimal literal
